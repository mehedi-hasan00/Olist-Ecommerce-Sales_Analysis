# %%
import pandas as pd
import numpy as np

# %%
data_path = 'olist_dataset/'
orders = pd.read_csv(data_path+'olist_orders_dataset.csv')
order_items = pd.read_csv(data_path+'olist_order_items_dataset.csv')
customers = pd.read_csv(data_path+'olist_customers_dataset.csv')
products = pd.read_csv(data_path+'olist_products_dataset.csv')
payments = pd.read_csv(data_path+'olist_order_payments_dataset.csv')
reviews = pd.read_csv(data_path+'olist_order_reviews_dataset.csv')
category_translation = pd.read_csv(data_path+'product_category_name_translation.csv')
sellers = pd.read_csv('olist_dataset/olist_sellers_dataset.csv')

# %%
for name, df_ in [('orders',orders),('order_items',order_items),('customers',customers),('products',products),('payments',payments),('reviews',reviews)]:
    print(f"{name}:{df_.shape}")
# Out:
# orders:(99441, 8)
# order_items:(112650, 7)
# customers:(99441, 5)
# products:(32951, 9)
# payments:(103886, 5)
# reviews:(99224, 7)

# %% [markdown]
# #### Order dataset

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.dtypes
# Out:
# order_id                         str
# customer_id                      str
# order_status                     str
# order_purchase_timestamp         str
# order_approved_at                str
# order_delivered_carrier_date     str
# order_delivered_customer_date    str
# order_estimated_delivery_date    str
# dtype: object

# %% [markdown]
# #### All are in tring datatype we have to change the data type string to datetime

# %%
date_cols = [
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
]
for col in date_cols:
    orders[col] = pd.to_datetime(orders[col])

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.dtypes
# Out:
# order_id                                    str
# customer_id                                 str
# order_status                                str
# order_purchase_timestamp         datetime64[us]
# order_approved_at                datetime64[us]
# order_delivered_carrier_date     datetime64[us]
# order_delivered_customer_date    datetime64[us]
# order_estimated_delivery_date    datetime64[us]
# dtype: object

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders[orders['order_status'] == 'delivered'].isnull().sum()
# Out:
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                14
# order_delivered_carrier_date      2
# order_delivered_customer_date     8
# order_estimated_delivery_date     0
# dtype: int64

# %%
orders_clean = orders[orders['order_status'] == 'delivered'].copy()

# %%
orders_clean = orders_clean.dropna()

# %%
orders_clean.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
orders_clean.shape
# Out:
# (96455, 8)

# %% [markdown]
# #### To check is there any wrong date.

# %%
invalid_date = orders_clean[orders_clean['order_delivered_customer_date']< orders_clean['order_purchase_timestamp']]
print("Invalid records count:", len(invalid_date))
# Out:
# Invalid records count: 0

# %% [markdown]
# ##### All are valid date.

# %% [markdown]
# ### Product dataset

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# #### Product category name are in Portuguese language, we have to translate it into English Language using category translation

# %%
products_clean = products.merge(
    category_translation,
    on = 'product_category_name',
    how= 'left'
)

# %%
products_clean.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products_clean.drop(columns = ['product_category_name'], inplace = True)
products_clean.rename(columns={'product_category_name_english':'product_category_name'}, inplace = True)

# %%
products_clean.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 44.0
# 2  96bd76ec8810374ed1b65e291975717f                 46.0
# 3  cef67bcfe19066a932b7673e239eb23d                 27.0
# 4  9dc1a7de274444849c219cff195d0b71                 37.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       276.0                 1.0            1000.0
# 2                       250.0                 1.0             154.0
# 3                       261.0                 1.0             371.0
# 4                       402.0                 4.0             625.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               16.0               10.0              14.0
# 1               30.0               18.0              20.0
# ...

# %%
products_clean.isnull().sum()
# Out:
# product_id                      0
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# product_category_name         623
# dtype: int64

# %%
products_clean['product_category_name'] = products_clean['product_category_name'].fillna('unknown')

# %%
products_clean.isnull().sum()
# Out:
# product_id                      0
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# product_category_name           0
# dtype: int64

# %%
products_clean = products_clean.dropna()

# %%
products_clean.isnull().sum()
# Out:
# product_id                    0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# product_category_name         0
# dtype: int64

# %%
products_clean.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 44.0
# 2  96bd76ec8810374ed1b65e291975717f                 46.0
# 3  cef67bcfe19066a932b7673e239eb23d                 27.0
# 4  9dc1a7de274444849c219cff195d0b71                 37.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       276.0                 1.0            1000.0
# 2                       250.0                 1.0             154.0
# 3                       261.0                 1.0             371.0
# 4                       402.0                 4.0             625.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               16.0               10.0              14.0
# 1               30.0               18.0              20.0
# ...

# %% [markdown]
# ### Customer Dataset

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers['customer_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers_clean = customers.copy()
customers_clean['customer_city'] = customers_clean['customer_city'].str.lower().str.strip() #loweer case all the city name and trim the space
customers_clean['customer_state'] = customers_clean['customer_state'].str.upper().str.strip() #uper case all the state name and trim the space

# %%
customers_clean.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 44053  0ba31c6990ca00aca5d0818cd491013c  85740013af25892ebf157244609328cf
# 25352  c1811682bcf67e76e41b49d217e69704  83ae3211482988043fe83d0231270370
# 67558  0df8e68bdf469717f79bf1e89a7450e4  78151007275917661fd788d7ff1ce06d
# 6511   e2d332efaa3c6f6c394d00ee57547fec  1a43917020d9c84f3c37ca03f8a61e13
# 72813  edd54c79d42824d702691585dbf3fa39  4578d62c4ca82d84a7442229d96b6fc5
#
#        customer_zip_code_prefix         customer_city customer_state
# 44053                     74959  aparecida de goiania             GO
# 25352                     32145              contagem             MG
# 67558                      1531             sao paulo             SP
# 6511                      18055              sorocaba             SP
# 72813                      7142             guarulhos             SP

# %% [markdown]
# #### Fix the Zip Code

# %%
customers_clean['customer_zip_code_prefix'] = customers_clean['customer_zip_code_prefix'].astype(str).str.zfill(5)

# %%
customers_clean.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_zip_code_prefix          customer_city customer_state
# 0                    14409                 franca             SP
# 1                    09790  sao bernardo do campo             SP
# 2                    01151              sao paulo             SP
# 3                    08775        mogi das cruzes             SP
# 4                    13056               campinas             SP

# %% [markdown]
# ### Order Item Dataset

# %%
order_items.isnull().sum() # check missing value
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.duplicated().sum() # check duplicates
# Out:
# np.int64(0)

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items.dtypes # check datatype
# Out:
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object

# %%
order_items_clean = order_items.copy()

# %%
order_items_clean['shipping_limit_date'] = pd.to_datetime(order_items_clean['shipping_limit_date']) # convert datetime datatype

# %%
order_items_clean.dtypes
# Out:
# order_id                          str
# order_item_id                   int64
# product_id                        str
# seller_id                         str
# shipping_limit_date    datetime64[us]
# price                         float64
# freight_value                 float64
# dtype: object

# %% [markdown]
# #### Logical and Price check

# %%
invalid_prices = order_items_clean[(order_items_clean['price'] < 0) | (order_items_clean['freight_value'] < 0)]
print("Invalid prices count:", len(invalid_prices))
# Out:
# Invalid prices count: 0

# %% [markdown]
# ### Payment Dataset

# %%
payments.isnull().sum() # check missing value
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
invalid_payments = payments[payments['payment_value'] <= 0] # check invalid payment
print("Invalid payments count:", len(invalid_payments))
# Out:
# Invalid payments count: 9

# %%
payments_clean = payments[payments['payment_value'] > 0].copy()

# %% [markdown]
# ### Reviews Dataset

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
reviews.dtypes
# Out:
# review_id                    str
# order_id                     str
# review_score               int64
# review_comment_title         str
# review_comment_message       str
# review_creation_date         str
# review_answer_timestamp      str
# dtype: object

# %%
reviews_clean = reviews.copy()

# %%
reviews_clean['review_creation_date'] = pd.to_datetime(reviews_clean['review_creation_date'])
reviews_clean['review_answer_timestamp'] = pd.to_datetime(reviews_clean['review_answer_timestamp'])

# %%
reviews_clean.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
reviews_clean['review_comment_title'] = reviews_clean['review_comment_title'].fillna('no_title')
reviews_clean['review_comment_message'] = reviews_clean['review_comment_message'].fillna('no_comment')

# %%
reviews_clean.isnull().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# ### Sellers Dataset

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers_clean = sellers.copy()
sellers_clean['seller_city'] = sellers_clean['seller_city'].str.lower().str.strip() #loweer case all the city name and trim the space
sellers_clean['seller_state'] = sellers_clean['seller_state'].str.upper().str.strip() #uper case all the state name and trim the space

# %%
sellers_clean['seller_zip_code_prefix'] = sellers_clean['seller_zip_code_prefix'].astype(str).str.zfill(5)

# %%
sellers_clean.head()
# Out:
#                           seller_id seller_zip_code_prefix        seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                  13023           campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                  13844         mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                  20031     rio de janeiro
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                  04195          sao paulo
# 4  51a04a8a6bdcb23deccc82b0b80742cf                  12914  braganca paulista
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
# 3           SP
# 4           SP

# %% [markdown]
# #### Save the clean data set

# %%
orders_clean.to_csv('olist_dataset/orders_clean.csv', index=False)
products_clean.to_csv('olist_dataset/products_clean.csv', index=False)
customers_clean.to_csv('olist_dataset/customers_clean.csv', index=False)
order_items_clean.to_csv('olist_dataset/order_items_clean.csv', index=False)
payments_clean.to_csv('olist_dataset/payments_clean.csv', index=False)
reviews_clean.to_csv('olist_dataset/reviews_clean.csv', index=False)
sellers_clean.to_csv('olist_dataset/sellers_clean.csv',  index=False)

print("All clean datasets saved successfully!")
# Out:
# All clean datasets saved successfully!
